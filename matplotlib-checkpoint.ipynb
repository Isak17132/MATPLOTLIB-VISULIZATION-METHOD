# %%
from scipy import constants

# %%
from scipy import constants

print(constants.liter)
# Out:
# 0.001

# %% [markdown]
# import python libraries
#
#
# |

# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as ps

# %%
print(mat.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ISAK\Downloads\python proj\matplotlib.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ISAK/Downloads/python%20proj/matplotlib.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> print(mat.__version__)
#
# NameError: name 'mat' is not defined

# %% [markdown]
# # criate a graph

# %%
x = np.array([0,5])
y = np.array([0,7])
z = np.array([-5,7])

plt.plot(x,y,z)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# # criate a graph using doutts

# %%
x = np.array([0,5])
y = np.array([0,7])
z = np.array([5,7])
plt.plot(x,y,'o',z,'o')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([2,6,8,12])
y = np.array([3,4,7,9])
z = np.array([1,5,10,11])
plt.plot(x,y,'o',z,'p')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# # creat a zic zac graph

# %%
x = np.array([0,3,1,5,4])

plt.plot(x)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
z = np.array([1,5,10,11])
plt.plot(z,'p-.m')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# # change the color and size

# %%
x = np.array([2,6,8,12])

plt.plot(x , marker = 'p', ms = 30 , mec = 'g' , mfc ='r')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# change the pattern in line
y = np.array([3,4,7,9])

plt.plot(y, ls =':')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# change rhe coolor in line
x = np.array([2,6,8,12])

plt.plot(x, c = 'hotpink')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# change the size in line
z = np.array([1,5,10,11])
plt.plot(z, lw = "15.50")
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# use 2 grap line
x1 = np.array([2,6,8,12])
x2 = np.array([3,6,7,12])

plt.plot(x1)
plt.plot(x2)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# add tittel and lable in graph
x = np.array([2,6,3,5])

y = np.array([3,4,7,9])
font1 = {'family':'serif','color':'blue','size':20}
font3 = {'family':'serif','color':'darkred','size':15}

plt.title("match graph" , fontdict = font1 , loc = 'right')
plt.xlabel("ball" , fontdict = font3)
plt.ylabel("run",fontdict = font3)
plt.plot(x,y)

print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# add background line in graph
x = np.array([2,6,3,5])
y = np.array([3,4,7,9])

plt.title("match graph" ) 
plt.xlabel("ball" )
plt.ylabel("run")
plt.plot(x,y)
plt.grid()
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# 
x = np.array([2,6,3,5])
y = np.array([3,4,7,9])

plt.title("match graph" ) 
plt.xlabel("ball" )
plt.ylabel("run")
plt.plot(x,y)
plt.grid(axis = "x")
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([2,6,3,5])
y = np.array([3,4,7,9])

plt.title("match graph" ) 
plt.xlabel("ball" )
plt.ylabel("run")
plt.plot(x,y)
plt.grid(c = "g" , ls = ":" , lw = 1)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([0,2,4,6])
y = np.array([11,3,16,5])
 
plt.subplot(2,1,1)
plt.plot(x,y)

x = np.array([0,2,4,6])
y = np.array([10,30,60,90])
 
plt.subplot(2,1,2)
plt.plot(x,y)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)


x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y , c ='b')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors)
plt.colorbar()
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = ("A","B","C","D")
y = (6,8,2,7)
plt.bar(x,y)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = ("A","B","C","D")
y = (6,8,2,7)
plt.barh(x,y)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = ("A","B","C","D")
y = (6,8,2,7)
plt.bar(x, y , color = ["g","r","b","black"])
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x =("A","B","C","D")
y = (6,8,2,7)
plt.bar(x,y , color = "r" , width = 0.11)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = ("A","B","C","D")
y = (6,8,2,7)
plt.barh(x,y , height = 0.5)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.random.normal(175,20,786)
plt.hist(x)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = (25,25,20,30)
plt.pie(x)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = (25,25,20,30)
ml = ["apple","mango","banana","kiwi"]
plt.pie(x , labels = ml , startangle = 180 )
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([25,25,20,30])
ml = ["apple","mango","banana","kiwi"]
mx = [0.3,0.1,0,0.2]
plt.pie(x , labels = ml , startangle = 180 , explode = mx )
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([25,25,20,30])
ml = ["apple","mango","banana","kiwi"]
mx = [0.3,0.1,0,0.2]
plt.pie(x , labels = ml , startangle = 180 , explode = mx , shadow = True)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([25,25,20,30])
ml = ["apple","mango","banana","kiwi"]
mc = ["black","pink","yellow","blue"]
plt.pie(x , labels = ml , colors = mc )
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([25,25,20,30])
ml = ["apple","mango","banana","kiwi"]
plt.pie(x , labels = ml )
plt.legend(title ='fruts name' , bbox_to_anchor = (1.1,1)  )
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([0,5])
y = np.array([0,7])
z = np.array([-5,7])
plt.stackplot(x,y,z)
plt.plot(x,y,z)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ISAK\\anaconda\\conda-meta\\AC\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([0,5])
y = np.array([0,7])
z = np.array([-5,7])
plt.sf_dual(x,y,z)
plt.plot(x,y,z)
print(plt)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 4
#       2 y = np.array([0,7])
#       3 z = np.array([-5,7])
# ----> 4 plt.sf_dual(x,y,z)
#       5 plt.plot(x,y,z)
#       6 print(plt)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'sf_dual'
